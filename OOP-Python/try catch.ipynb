# %%
def toplama(numara1,numara2):
  return numara1 + numara2

# %%
x = int(input("ilk numarayi giriniz: "))
y = int(input("ikinci numarayi giriniz: "))
toplama(x,y)
# Out:
# ilk numarayi giriniz: 1
# ikinci numarayi giriniz: 2
# 3

# %% [markdown]
# # try & except & else & finally

# %%
while True:
  try:
    benimInt = int(input("numaranızı giriniz : "))
  except:
    print("lutfen gercek numara giriniz")
    continue
  else:
    print("tesekkurler")
    break
  finally:
    print("finally çagrıldı")
# Out:
# numaranızı giriniz : atıl
# lutfen gercek numara giriniz
# finally çagrıldı
# numaranızı giriniz : 322edfjdsh
# lutfen gercek numara giriniz
# finally çagrıldı
# numaranızı giriniz : fuısehyı8389r
# lutfen gercek numara giriniz
# finally çagrıldı
# numaranızı giriniz : 12
# tesekkurler
# finally çagrıldı
