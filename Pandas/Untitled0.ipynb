# %%
import numpy as np
import pandas as pd

# %%
sozluk = {
    "column_1" : [1,2,3,4,1,6,1],
    "column_2" : [5,6,7,8,8,9,10]
}

# %%
dataFrame = pd.DataFrame(sozluk)

# %%
dataFrame
# Out:
#    column_1  column_2
# 0         1         5
# 1         2         6
# 2         3         7
# 3         4         8
# 4         1         8
# 5         6         9
# 6         1        10

# %%
dataFrame.describe().T
# Out:
#           count      mean       std  min  25%  50%  75%   max
# column_1    7.0  2.571429  1.902379  1.0  1.0  2.0  3.5   6.0
# column_2    7.0  7.571429  1.718249  5.0  6.5  8.0  8.5  10.0

# %%
dataFrame.column_1.unique() #sutundaki tekrarsız degerler
# Out:
# array([1, 2, 3, 4, 6])

# %%
dataFrame.column_1.value_counts()
# Out:
# column_1
# 1    3
# 2    1
# 3    1
# 4    1
# 6    1
# Name: count, dtype: int64
